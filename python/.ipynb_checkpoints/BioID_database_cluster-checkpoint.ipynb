# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import sklearn
import cv2
import os
import face_recognition

# %%
os.chdir('/home/huy/Downloads/face-dataset/BioID-FaceDatabase-V1.2/')

# %%
images = []
bounding_boxs = []
for entry in os.scandir():
    if entry.is_file() and entry.name.endswith('.pgm'):
        img = face_recognition.load_image_file(entry.path)
        images.append(img)
        bounding_boxs.append(face_recognition.face_locations(img))

# %%
with open('images.pickle', 'wb') as file:
    pickle.dump(images, file)
with open('bounding_boxs.pickle', 'wb') as file:
    pickle.dump(bounding_boxs, file)

# %%
indices = [index for index, value in enumerate(bounding_boxs) if value == []]

# %%
for i, val in enumerate(indices):
    del images[val-i]
    del bounding_boxs[val-i]

# %%
len(images)
len(bounding_boxs)
# Out:
# 1511

# %%
encoded_faces = []
for i, img in enumerate(images):
    encoded = face_recognition.face_encodings(img, known_face_locations=bounding_boxs[i])
    encoded_faces.append(encoded)

# %%
with open('encoded_faces.pickle', 'wb') as file:
    pickle.dump(encoded_faces, file)

# %%
len(encoded_faces)
# Out:
# 1511

# %%
from sklearn.cluster import DBSCAN

# %%
clt = DBSCAN(metric='euclidean')

# %%
encoded_faces = [x[0] for x in encoded_faces]

# %%
clt.fit(encoded_faces)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-7a4ba34830f6> in <module>
# ----> 1 clt.fit(encoded_faces)
#
# ~/.local/lib/python3.6/site-packages/sklearn/cluster/dbscan_.py in fit(self, X, y, sample_weight)
#     347
#     348         """
# --> 349         X = check_array(X, accept_sparse='csr')
#     350         clust = dbscan(X, sample_weight=sample_weight,
#     351                        **self.get_params())
#
# ~/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     519                     "Reshape your data either using array.reshape(-1, 1) if "
#     520                     "your data has a single feature or array.reshape(1, -1) "
# --> 521                     "if it contains a single sample.".format(array))
#     522
#     523         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[list([array([-0.13578141,  0.01721197,  0.08688055, -0.00686496, -0.11885749,
#        -0.08914565, -0.01481601, -0.09643715,  0.00343636, -0.12366533,
#         0.12856653, -0.03774639, -0.1609298 ,  0.01143718,  0.01832448,
#         0.09413897, -0.07632492, -0.13371228, -0.14437848, -0.08393433,
#         0.03297175,  0.00885034, -0.11076111, -0.02613727, -0.0745005 ,
#        -0.24648367, -0.08616084, -0.03834344,  0.05593729, -0.01635175,
#         0.03494554,  0.0287645 , -0.1249928 , -0.01309592,  0.02920412,
#         0.12184819, -0.09244669, -0.06075375,  0.23486857,  0.01759472,
#        -0.17082012,  0.01511022,  0.12200112,  0.24593101,  0.13711026,
#         0.06607924,  0.02922515,  0.00558148,  0.12102623, -0.23983124,
#         0.059308  ,  0.13403438,  0.1727033 ,  0.11734112,  0.12575983,
#        -0.14829545,  0.10437562,  0.05618599, -0.19524798,  0.08786944,
#         0.06621828, -0.15022837, -0.06062613, -0.04132242,  0.17797482,
#         0.12725054, -0.00887278, -0.10819725,  0.21618819, -0.19123468,
#        -0.12585446,  0.01880928, -0.08827344, -0.09564048, -0.24773258,
